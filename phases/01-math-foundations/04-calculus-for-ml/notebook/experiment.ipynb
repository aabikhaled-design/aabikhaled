# %% [markdown]
# # Calculus for Machine Learning: Interactive Visual Explorer
#
# > Derivatives tell you which way is downhill. That is all a neural network needs to learn.
#
# Welcome to the interactive notebook companion for **Calculus for Machine Learning**.

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8-whitegrid' if 'seaborn-v0_8-whitegrid' in plt.style.available else 'default')
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 11
